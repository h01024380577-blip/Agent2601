# %%
print('Hello Jupyter')
# Out:
# Hello Jupyter

# %%
# !where python
# Out:
# D:\MCP2601\AgentWork\.venv\Scripts\python.exe
# C:\Users\User\AppData\Local\Programs\Python\Python312\python.exe
# C:\Users\User\AppData\Local\Microsoft\WindowsApps\python.exe
